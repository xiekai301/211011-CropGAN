# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.imshow(np.ones((128,128)).astype(np.uint8), cmap='gray'); plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
#This works:

#This fails
a = np.asarray([[0.1,0.2],[0.3,0.4]], dtype=np.float16)
plt.imshow(a), plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/.conda/envs/tf/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/.conda/envs/tf/lib/python3.7/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ...

# %%
a = np.asarray([[0.1,0.2],[0.3,0.4]], dtype=np.float64)
plt.imshow(a), plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x7f76e9a60fd0>, None)

# %%
(np.ones((128,128))*255).astype(np.uint8)
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
npy_name = 'dataset/0000.npz'
img_files = np.load(npy_name)
img = img_files['vol_data']

plt.imshow(img[-1,:,:], cmap='gray')
plt.show()

# %%
npy_name = 'dataset/0002.npz'
img_files = np.load(npy_name)
img = img_files['vol_data']

plt.imshow(img[240,:,:], cmap='gray')
plt.show()

# %%
from scipy.io import loadmat
reg = loadmat('/tmp/tmp1ph3m3t40GenericAffine.mat')

# %%
reg['AffineTransform_float_3_3']
# Out:
# array([[ 9.9993086e-01],
#        [ 2.7956704e-03],
#        [ 1.1418894e-02],
#        [-2.8094854e-03],
#        [ 9.9999529e-01],
#        [ 1.1939678e-03],
#        [-1.1415503e-02],
#        [-1.2259664e-03],
#        [ 9.9993408e-01],
#        [ 4.4725819e+01],
#        [ 1.9413639e+01],
#        [ 6.0398073e+00]], dtype=float32)

# %%
reg['fixed']
# Out:
# array([[-131.1648   ],
#        [   9.346453 ],
#        [  -1.6065156]], dtype=float32)
